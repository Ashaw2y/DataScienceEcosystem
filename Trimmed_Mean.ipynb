# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashaw2y/DataScienceEcosystem/blob/main/Trimmed_Mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_excel("/content/EXPORT.XLSX")
df.columns
# Out:
# Index(['Site', 'Site_1', 'Article', 'Article Number', 'Mdse Cat.', 'p1', 'p2',
#        'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13',
#        'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23',
#        'p24', 'Days_in_ ezaby', 'Max_Receipt', 'Total_Sales'],
#       dtype='object')

# %%
df['D'] = stats.trim_mean(df[['p1', 'p2',
       'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13',
       'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23',
       'p24']], 0.1, axis=1)
df
# Out:
#        Site   Site_1     Article                            Article Number  \
# 0      1000  Elezaby          97       SYRINGE 3ML ADULT KOREA (23GХ1.25)▓
# 1      1000  Elezaby          23                        SYRINGE 3ML ADULT▓
# 2      1000  Elezaby      340139           CONTROLOC 40MG 14/TAB.+(EX.NEW)
# 3      1000  Elezaby  3401397777              CONTROLOC 40MG 14/TAB.+(NEW)
# 4      1000  Elezaby          24                              SYRINGE 5ML▓
# ...     ...      ...         ...                                       ...
# 15949  1000  Elezaby  3418217777          CRYPTONAZ 100MG (60ML) SUSP(NEW)
# 15950  1000  Elezaby      341821       CRYPTONAZ 100MG (60ML) SUSP(EX.NEW)
# 15951  1000  Elezaby      114109  FRIGG PACIFIER PACK OF 1 ROPE POWDE.BLUE
# 15952  1000  Elezaby     1151010       FRIGG PACIFIER PACK OF 1 SOFT LILAC
# 15953  1000  Elezaby     3206950          ALFA VITAMIN D3 5000IU 100/CAP+▓
#
# ...

# %%
df.to_excel('steady sales2.xlsx', index = False)
